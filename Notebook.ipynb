# %%
import pickle

# %%
pickle.dump('0_news_articles.csv',open('news.pkl','wb'))

# %%
import pandas as pd

# %%
data = pd.read_csv(r'0_news_articles.csv')

# %%
data
# Out:
#       Article_id                                              Title  \
# 0              0  Fire at Vaishno Devi shrine complex; cash coun...
# 1              1  Had not gone to meet Nawaz Sharif, says Uddhav...
# 2              2  Corruption case: Former Haryana I-T deputy com...
# 3              3  Kannur MP K Sudhakaran appointed chief of Cong...
# 4              4  Kerala girl of Class 5 writes to CJI, lauds SC...
# ...          ...                                                ...
# 2245        2245  Malaika Arora shares yoga asanas for healthy, ...
# 2246        2246  COVID-19 diet: Khichdi is a ‘safe’ option; oth...
# 2247        2247  ‘Keep listening. The world wants to hear your ...
# 2248        2248  Forget cold drinks, switch to refreshing bael ...
# 2249        2249  ‘Love wins’: Rita Wilson and Tom Hanks celebra...
#
#                                             Description  \
# 0     No one was injured in the fire, which broke ou...
# ...

# %%
import pickle

# %%
pickle.dump(data,open('News.pkl','wb'))

# %%
pickle.dump(data,open('News.pkl','wb'))

# %%
pickle.dump('data',open('news.pkl','wb'))

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\vishu

# %%
pickle.dump(data, open(r'C:\Users\vishu\News.pkl', 'wb'))

# %%
data['Title'].values
# Out:
# array(['Fire at Vaishno Devi shrine complex; cash counter damaged',
#        'Had not gone to meet Nawaz Sharif, says Uddhav Thackeray as he plays down one-on-one meeting with PM Modi',
#        'Corruption case: Former Haryana I-T deputy commissioner gets 4 years in prison',
#        ...,
#        '‘Keep listening. The world wants to hear your ideas, good and bad’: Matt Damon',
#        'Forget cold drinks, switch to refreshing bael sherbet this summer',
#        '‘Love wins’: Rita Wilson and Tom Hanks celebrate 33 years of marriage'],
#       dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import pandas as pd
import pickle

# Example: assuming `user` is your DataFrame with a 'Title' column
vectorizer = TfidfVectorizer(analyzer='word')
tfidf_matrix = vectorizer.fit_transform(user['Title'])

# Compute cosine similarity
similarity = linear_kernel(tfidf_matrix, tfidf_matrix)   # ✅ store as 'similarity'

# Index of titles
indices = pd.Series(user.index, index=user['Title']).drop_duplicates()

# Save the similarity matrix
pickle.dump(similarity, open('similarity.pkl', 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 8
#       6 # Example: assuming `user` is your DataFrame with a 'Title' column
#       7 vectorizer = TfidfVectorizer(analyzer='word')
# ----> 8 tfidf_matrix = vectorizer.fit_transform(user['Title'])
#      10 # Compute cosine similarity
#      11 similarity = linear_kernel(tfidf_matrix, tfidf_matrix)   # ✅ store as 'similarity'
#
# NameError: name 'user' is not defined

# %%
user = pd.read_csv(r'2_user_interest.csv')

# %%
user
# Out:
#       Unnamed: 0  Article_id  \
# 0              0           0
# 1              1           1
# 2              2           2
# 3              4           4
# 4              8           8
# ...          ...         ...
# 1108        2244        2244
# 1109        2245        2245
# 1110        2246        2246
# 1111        2247        2247
# 1112        2248        2248
#
#                                                   Title  \
# 0     Fire at Vaishno Devi shrine complex; cash coun...
# 1     Had not gone to meet Nawaz Sharif, says Uddhav...
# 2     Corruption case: Former Haryana I-T deputy com...
# 3     Kerala girl of Class 5 writes to CJI, lauds SC...
# 4     Dantewada: 24-year-old tribal woman killed in ...
# ...                                                 ...
# 1108  How learning about your genes can help with yo...
# 1109  Malaika Arora shares yoga asanas for healthy, ...
# 1110  COVID-19 diet: Khichdi is a ‘safe’ option; oth...
# ...

# %%
vectorizer = TfidfVectorizer(analyzer = 'word')
tfidf_matrix = vectorizer.fit_transform(user['Title'])
tfidf_matrix.shape
# Out:
# (1113, 4451)

# %%
# cosine-similarity (linear kernel)
cosine_similarity = linear_kernel(tfidf_matrix, tfidf_matrix)

# index of Title
indices = pd.Series(user['Title'].index)

# %%
import pickle

# Save the article dataset and similarity matrix
pickle.dump(user, open('news_articles.pkl', 'wb'))
pickle.dump(cosine_similarity, open('similarity.pkl', 'wb'))

# %%
userInterest = pd.read_csv(r'3_user_rated_articles.csv')

# %%
pickle.dump(userInterest, open('user_rated_articles.pkl', 'wb'))
