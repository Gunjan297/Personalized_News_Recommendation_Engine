# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import string
import re

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.2)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.4.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.0)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 73.5 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import gensim
from gensim import corpora, models, similarities

import nltk
from nltk.corpus import stopwords

# %%
import scipy
from scipy.spatial.distance import cdist
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import svds
from scipy.linalg import svd

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r'0_news_articles.csv')
data.head()
data.shape
# Out:
# (2250, 6)

# %%
user = pd.read_csv(r'2_user_interest.csv')
print(user.shape)
user.drop(columns= user.columns[0],
        axis=1,
        inplace=True)
user.head()
# Out:
# (1113, 11)
#    Article_id                                              Title  \
# 0           0  Fire at Vaishno Devi shrine complex; cash coun...
# 1           1  Had not gone to meet Nawaz Sharif, says Uddhav...
# 2           2  Corruption case: Former Haryana I-T deputy com...
# 3           4  Kerala girl of Class 5 writes to CJI, lauds SC...
# 4           8  Dantewada: 24-year-old tribal woman killed in ...
#
#                                          Description  \
# 0  No one was injured in the fire, which broke ou...
# 1  Uddhav Thackeray led a delegation of his cabin...
# 2  It was in 2016 that the CBI had arrested Nitin...
# 3  Chief Justice N V Ramana responded to the Clas...
# 4  The victim's mother alleged she was raped, and...
#
#                        Date  \
# 0   June 8, 2021 7:28:32 pm
# 1   June 8, 2021 6:56:40 pm
# 2  June 8, 2021  6:25:24 pm
# 3  June 8, 2021  4:43:10 pm
# 4  June 8, 2021  2:53:00 pm
#
#                                                  URL  UserId  SessionId  \
# 0  https://indianexpress.com/article/india/vaishn...       1          1
# 1  https://indianexpress.com/article/india/had-no...       1          1
# 2  https://indianexpress.com/article/india/corrup...       1          1
# 3  https://indianexpress.com/article/india/kerala...       1          1
# 4  https://indianexpress.com/article/india/chhatt...       1          1
#
#    Article Rank  Click  Time Spent (seconds)
# 0             1   True                    25
# 1             2   True                    14
# 2             3   True                    57
# 3             5   True                    62
# 4             9   True                    77

# %%
vectorizer = TfidfVectorizer(analyzer = 'word')
tfidf_matrix = vectorizer.fit_transform(user['Title'])
tfidf_matrix.shape
# Out:
# (1113, 4451)

# %%
# cosine-similarity (linear kernel)
cosine_similarity = linear_kernel(tfidf_matrix, tfidf_matrix)

# index of Title
indices = pd.Series(user['Title'].index)

# %%
# making predictions

def recommendation(index, method):
    id = indices[index]

    # fetching the top 10 articles

    similarity_score = list(enumerate(method[id]))
    similarity_score = sorted(similarity_score, key = lambda x: x[1], reverse = True)
    similarity_score = similarity_score[1:11]

    # get the article index
    news_index = [i[0] for i in similarity_score]

    # returning the top 10 most similar books
    return user['Title'].iloc[news_index]

# %%
# obtaining random input
input = user.sample()
input
# Out:
#      Article_id                                              Title  \
# 953        1920  ‘I identify as non-binary; will officially be ...
#
#                                            Description  \
# 953  "Sharing this with you now opens another level...
#
#                          Date  \
# 953  May 19, 2021  7:51:03 pm
#
#                                                    URL  UserId  SessionId  \
# 953  https://indianexpress.com/article/lifestyle/li...    1910       1905
#
#      Article Rank  Click  Time Spent (seconds)
# 953             1   True                    28

# %%
# passing the input
recommendation(24, cosine_similarity)
# Out:
# 24     Rights of Mehul Choksi will be respected, cour...
# 300    Fugitive businessman Mehul Choksi held in Domi...
# 85     After a week-long wait for Mehul Choksi in Dom...
# 188    Jet in Dominica with Choksi case papers from I...
# 52     Antigua police has started investigating Mehul...
# 189    Choksi may have taken his girlfriend to Domini...
# 136    ‘Covid waves will keep coming, we have to be p...
# 353     PM Modi-led panel meets to decide next CBI chief
# 84     Writing to Queen, will urge her to intervene s...
# 693    Players views must be respected after Palestin...
# Name: Title, dtype: object
